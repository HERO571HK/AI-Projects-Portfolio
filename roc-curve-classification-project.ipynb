# %% [markdown]
# # ROC Curve Classification Project
#
# ## Proje Amacı
# Bu projede Iris veri seti kullanılarak ROC Curve analizi gerçekleştirilecektir.
#
# Bu proje ile:
# - Classification
# - ROC Curve
# - AUC Score
# - Model Evaluation
#
# uygulamaları yapılacaktır.
#
# ---
#
# # Proje Yol Haritası
#
# 1. Dataset yükleme
# 2. X ve y oluşturma
# 3. Train Test Split
# 4. Model kurma
# 5. ROC Curve oluşturma
# 6. Sonuç değerlendirme

# %%
# Gerekli kütüphaneler

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Dataset

iris = load_iris()

X = iris.data
y = iris.target

# Binary hale getiriyoruz
y = label_binarize(y, classes=[0,1,2])
y = y[:,0]

# Split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# Model

model = LogisticRegression()

model.fit(X_train,y_train)

y_score = model.predict_proba(X_test)[:,1]

# ROC

fpr,tpr,_ = roc_curve(y_test,y_score)

roc_auc = auc(fpr,tpr)

plt.figure()

plt.plot(fpr,tpr,label="AUC="+str(roc_auc))

plt.plot([0,1],[0,1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")

plt.legend()

plt.show()

print("AUC Score:",roc_auc)
# Out:
# AUC Score: 1.0

# %% [markdown]
# # Sonuç ve Değerlendirme
#
# Bu projede ROC Curve ve AUC Score kullanılarak model performansı değerlendirilmiştir.
#
# AUC skorunun 1.0 olması modelin sınıfları yüksek doğrulukla ayırabildiğini göstermektedir.
#
# Bu proje ile:
#
# - ROC Curve
# - AUC Score
# - Logistic Regression
# - Model Evaluation
#
# uygulamaları başarıyla tamamlanmıştır.
