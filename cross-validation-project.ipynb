# %% [markdown]
# # Cross Validation Project
#
# ## Proje Amacı
# Bu projede Iris veri seti kullanılarak Cross Validation yöntemi ile model performansı değerlendirilecektir.
#
# Bu proje ile:
#
# - Classification
# - Cross Validation
# - Accuracy Evaluation
# - Model Validation
#
# uygulamaları yapılacaktır.
#
# ---
#
# # Proje Yol Haritası
#
# 1. Dataset yükleme
# 2. X ve y oluşturma
# 3. Model oluşturma
# 4. Cross Validation uygulama
# 5. Sonuç değerlendirme

# %%
# Gerekli kütüphaneler

import pandas as pd

from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# Dataset yükleme

iris = load_iris()

X = iris.data
y = iris.target

# Model

model = LogisticRegression(max_iter=1000)

# Cross Validation

scores = cross_val_score(
    model,
    X,
    y,
    cv=5
)

print("Cross Validation Scores:")

print(scores)

print()

print("Ortalama Başarı:", scores.mean())
# Out:
# Cross Validation Scores:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
#
# Ortalama Başarı: 0.9733333333333334

# %% [markdown]
# # Sonuç ve Değerlendirme
#
# Bu projede Cross Validation yöntemi kullanılarak model performansı değerlendirilmiştir.
#
# Ortalama başarı oranı modelin farklı veri bölünmelerinde tutarlı sonuçlar verdiğini göstermektedir.
#
# Bu proje ile:
#
# - Cross Validation
# - Model Validation
# - Accuracy Evaluation
# - Logistic Regression
#
# uygulamaları başarıyla tamamlanmıştır.
