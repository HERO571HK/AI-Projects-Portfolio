# %% [markdown]
# # Final Evaluation Project
#
# ## Proje Amacı
#
# Bu projede makine öğrenmesi modelleri genel olarak değerlendirilmekte ve proje boyunca öğrenilen yöntemler özetlenmektedir.
#
# Bu proje ile:
#
# - Classification
# - Model Evaluation
# - Accuracy Analysis
# - Machine Learning Workflow
#
# uygulamaları değerlendirilecektir.
#
# ---
#
# # Proje Yol Haritası
#
# 1. Veri seti yükleme
# 2. Model oluşturma
# 3. Model performans değerlendirmesi
# 4. Sonuçların karşılaştırılması
# 5. Genel değerlendirme

# %%
# Genel proje özeti

project_summary = {

"Tamamlanan Proje Sayısı":36,

"Kullanılan Ana Algoritmalar":[
"Decision Tree",
"Random Forest",
"KNN",
"SVM",
"Logistic Regression",
"Naive Bayes",
"Gradient Boosting",
"AdaBoost",
"CNN",
"ANN",
"NLP",
"PCA",
"K-Means"
],

"Öğrenilen Konular":[
"Classification",
"Clustering",
"Feature Selection",
"Cross Validation",
"Hyperparameter Tuning",
"ROC Curve",
"Recommendation Systems"
]

}

for key,value in project_summary.items():

    print(key,":")

    print(value)

    print()
# Out:
# Tamamlanan Proje Sayısı :
# 36
#
# Kullanılan Ana Algoritmalar :
# ['Decision Tree', 'Random Forest', 'KNN', 'SVM', 'Logistic Regression', 'Naive Bayes', 'Gradient Boosting', 'AdaBoost', 'CNN', 'ANN', 'NLP', 'PCA', 'K-Means']
#
# Öğrenilen Konular :
# ['Classification', 'Clustering', 'Feature Selection', 'Cross Validation', 'Hyperparameter Tuning', 'ROC Curve', 'Recommendation Systems']

# %% [markdown]
# # Genel Sonuç
#
# Bu eğitim sürecinde makine öğrenmesi ve derin öğrenme alanındaki temel ve ileri düzey uygulamalar tamamlanmıştır.
#
# Tamamlanan çalışmalar:
#
# - Supervised Learning
# - Unsupervised Learning
# - Deep Learning
# - NLP
# - Recommendation Systems
# - Model Optimization
# - Feature Engineering
#
# Bu süreç boyunca teorik ve uygulamalı çalışmalar başarıyla tamamlanmıştır.
