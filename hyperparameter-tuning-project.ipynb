# %% [markdown]
# # Hyperparameter Tuning Project
#
# ## Proje Amacı
# Bu projede GridSearchCV kullanılarak model parametre optimizasyonu gerçekleştirilecektir.
#
# Bu proje ile:
#
# - Hyperparameter Tuning
# - GridSearchCV
# - Model Optimization
# - Classification
#
# uygulamaları yapılacaktır.
#
# ---
#
# # Proje Yol Haritası
#
# 1. Dataset yükleme
# 2. X ve y oluşturma
# 3. Train Test Split
# 4. Model oluşturma
# 5. Grid Search uygulama
# 6. En iyi parametreleri bulma
# 7. Sonuç değerlendirme

# %%
# Gerekli kütüphaneler

import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Dataset yükleme

iris = load_iris()

X = iris.data
y = iris.target

# Split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# Model

rf = RandomForestClassifier()

# Parametreler

params = {
    "n_estimators":[50,100,150],
    "max_depth":[2,4,6,8]
}

# Grid Search

grid = GridSearchCV(
    rf,
    params,
    cv=5
)

grid.fit(X_train,y_train)

print("En iyi parametreler:")

print(grid.best_params_)

print()

print("En iyi skor:")

print(grid.best_score_)
# Out:
# En iyi parametreler:
# {'max_depth': 2, 'n_estimators': 50}
#
# En iyi skor:
# 0.95

# %% [markdown]
# # Sonuç ve Değerlendirme
#
# Bu projede GridSearchCV kullanılarak model için en uygun parametreler bulunmuştur.
#
# Hyperparameter tuning işlemi sayesinde model performansı optimize edilmiştir.
#
# Bu proje ile:
#
# - Hyperparameter Tuning
# - GridSearchCV
# - Model Optimization
# - Random Forest
#
# uygulamaları başarıyla tamamlanmıştır.
