# %% [markdown]
# # AdaBoost Classification Project
#
# ## Proje Amacı
# Bu projede Iris veri seti kullanılarak AdaBoost algoritması ile sınıflandırma işlemi gerçekleştirilecektir.
#
# Bu proje ile:
# - Classification
# - AdaBoost
# - Train Test Split
# - Accuracy Evaluation
# - Confusion Matrix
# - Classification Report
#
# uygulamaları yapılacaktır.
#
# ---
#
# # Proje Yol Haritası
#
# 1. Dataset yükleme
# 2. Veri inceleme
# 3. X ve y oluşturma
# 4. Train Test Split
# 5. AdaBoost modeli kurma
# 6. Tahmin işlemleri
# 7. Accuracy hesaplama
# 8. Confusion Matrix
# 9. Classification Report
# 10. Sonuç değerlendirmesi

# %%
# Iris datasetini yüklüyoruz

import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df["target"] = iris.target

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Veri yapısını inceliyoruz
df.info()

# İstatistiksel özet
df.describe()

# Eksik veri kontrolü
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# X ve y oluşturuyoruz

X = df.drop("target", axis=1)
y = df["target"]

# %%
# Train test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
# AdaBoost modelini kuruyoruz

from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

ab_model = AdaBoostClassifier(random_state=42)

ab_model.fit(X_train, y_train)

ab_pred = ab_model.predict(X_test)

ab_acc = accuracy_score(y_test, ab_pred)

print("AdaBoost Accuracy:", ab_acc)
# Out:
# AdaBoost Accuracy: 0.9333333333333333

# %% [markdown]
# # Confusion Matrix ve Classification Report
#
# Bu bölümde model performansı detaylı olarak incelenmektedir.

# %%
# Confusion matrix ve classification report alıyoruz

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print(confusion_matrix(y_test, ab_pred))

print(classification_report(y_test, ab_pred))
# Out:
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# # Sonuç ve Değerlendirme
#
# Bu projede Iris veri seti kullanılarak AdaBoost algoritması ile sınıflandırma işlemi gerçekleştirilmiştir.
#
# Modelin performansı accuracy, confusion matrix ve classification report ile değerlendirilmiştir.
#
# Bu proje ile:
# - Classification
# - AdaBoost
# - Accuracy Evaluation
# - Confusion Matrix
# - Classification Report
#
# uygulamaları başarıyla tamamlanmıştır.
